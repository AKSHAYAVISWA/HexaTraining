# %% [markdown]
# <a href="https://colab.research.google.com/github/AKSHAYAVISWA/HexaTraining/blob/main/June%208/%20google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("MyApp") \
    .getOrCreate()

# %%
data = [
    (101, "Rahul Sharma", "Data Engineering", 75000, "Hyderabad"),
    (102, "Priya Reddy", "AI Engineering", 85000, "Bangalore"),
    (103, "Amit Kumar", "Data Engineering", 65000, "Mumbai"),
    (104, "Sneha Patel", "Data Science", 95000, "Chennai"),
    (105, "Farhan Ali", "Cloud Engineering", 80000, "Delhi")
]

# %%
columns = [
    "employee_id",
    "name",
    "department",
    "salary",
    "city"
]

# %%
df=spark.createDataFrame(data, columns)
df.show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# +-----------+------------+-----------------+------+---------+

# %%
df.printSchema()
# Out:
# root
#  |-- employee_id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- department: string (nullable = true)
#  |-- salary: long (nullable = true)
#  |-- city: string (nullable = true)

# %%
df.select("name","salary").show()
# Out:
# +------------+------+
# |        name|salary|
# +------------+------+
# |Rahul Sharma| 75000|
# | Priya Reddy| 85000|
# |  Amit Kumar| 65000|
# | Sneha Patel| 95000|
# |  Farhan Ali| 80000|
# +------------+------+

# %%
df.filter(df.salary>80000).show()
# Out:
# +-----------+-----------+--------------+------+---------+
# |employee_id|       name|    department|salary|     city|
# +-----------+-----------+--------------+------+---------+
# |        102|Priya Reddy|AI Engineering| 85000|Bangalore|
# |        104|Sneha Patel|  Data Science| 95000|  Chennai|
# +-----------+-----------+--------------+------+---------+

# %%
df.filter(df.city == "Hyderabad").show()
# Out:
# +-----------+------------+----------------+------+---------+
# |employee_id|        name|      department|salary|     city|
# +-----------+------------+----------------+------+---------+
# |        101|Rahul Sharma|Data Engineering| 75000|Hyderabad|
# +-----------+------------+----------------+------+---------+

# %%
df.orderBy("salary").show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# +-----------+------------+-----------------+------+---------+

# %%
df.orderBy(df.salary.desc()).show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# +-----------+------------+-----------------+------+---------+

# %%
from pyspark.sql.functions import col
df_bonus = df.withColumn(
    "bonus",
     col("salary")*0.10
)
df_bonus.show()
# Out:
# +-----------+------------+-----------------+------+---------+------+
# |employee_id|        name|       department|salary|     city| bonus|
# +-----------+------------+-----------------+------+---------+------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|7500.0|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|8500.0|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|6500.0|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|9500.0|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|8000.0|
# +-----------+------------+-----------------+------+---------+------+

# %%
df_renamed = df.withColumnRenamed(
    "salary",
    "monthly_salary"
)
df_renamed.show()
# Out:
# +-----------+------------+-----------------+--------------+---------+
# |employee_id|        name|       department|monthly_salary|     city|
# +-----------+------------+-----------------+--------------+---------+
# |        101|Rahul Sharma| Data Engineering|         75000|Hyderabad|
# |        102| Priya Reddy|   AI Engineering|         85000|Bangalore|
# |        103|  Amit Kumar| Data Engineering|         65000|   Mumbai|
# |        104| Sneha Patel|     Data Science|         95000|  Chennai|
# |        105|  Farhan Ali|Cloud Engineering|         80000|    Delhi|
# +-----------+------------+-----------------+--------------+---------+

# %%
df.groupBy("department").count().show()
# Out:
# +-----------------+-----+
# |       department|count|
# +-----------------+-----+
# | Data Engineering|    2|
# |   AI Engineering|    1|
# |Cloud Engineering|    1|
# |     Data Science|    1|
# +-----------------+-----+

# %%
df.select("employee_id","name").show()
# Out:
# +-----------+------------+
# |employee_id|        name|
# +-----------+------------+
# |        101|Rahul Sharma|
# |        102| Priya Reddy|
# |        103|  Amit Kumar|
# |        104| Sneha Patel|
# |        105|  Farhan Ali|
# +-----------+------------+

# %%
df.select("name","salary","city").show()
# Out:
# +------------+------+---------+
# |        name|salary|     city|
# +------------+------+---------+
# |Rahul Sharma| 75000|Hyderabad|
# | Priya Reddy| 85000|Bangalore|
# |  Amit Kumar| 65000|   Mumbai|
# | Sneha Patel| 95000|  Chennai|
# |  Farhan Ali| 80000|    Delhi|
# +------------+------+---------+

# %%
df.drop("city").show()
# Out:
# +-----------+------------+-----------------+------+
# |employee_id|        name|       department|salary|
# +-----------+------------+-----------------+------+
# |        101|Rahul Sharma| Data Engineering| 75000|
# |        102| Priya Reddy|   AI Engineering| 85000|
# |        103|  Amit Kumar| Data Engineering| 65000|
# |        104| Sneha Patel|     Data Science| 95000|
# |        105|  Farhan Ali|Cloud Engineering| 80000|
# +-----------+------------+-----------------+------+

# %%
df.filter(df.salary>70000).show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# +-----------+------------+-----------------+------+---------+

# %%
df.filter(df.salary<80000).show()
# Out:
# +-----------+------------+----------------+------+---------+
# |employee_id|        name|      department|salary|     city|
# +-----------+------------+----------------+------+---------+
# |        101|Rahul Sharma|Data Engineering| 75000|Hyderabad|
# |        103|  Amit Kumar|Data Engineering| 65000|   Mumbai|
# +-----------+------------+----------------+------+---------+

# %%
df.filter(df.city=="Mumbai").show()
# Out:
# +-----------+----------+----------------+------+------+
# |employee_id|      name|      department|salary|  city|
# +-----------+----------+----------------+------+------+
# |        103|Amit Kumar|Data Engineering| 65000|Mumbai|
# +-----------+----------+----------------+------+------+

# %%
df.filter(df.city=="Bangalore").show()
# Out:
# +-----------+-----------+--------------+------+---------+
# |employee_id|       name|    department|salary|     city|
# +-----------+-----------+--------------+------+---------+
# |        102|Priya Reddy|AI Engineering| 85000|Bangalore|
# +-----------+-----------+--------------+------+---------+

# %%
df.filter(df.department=="Data Engineering").show()
# Out:
# +-----------+------------+----------------+------+---------+
# |employee_id|        name|      department|salary|     city|
# +-----------+------------+----------------+------+---------+
# |        101|Rahul Sharma|Data Engineering| 75000|Hyderabad|
# |        103|  Amit Kumar|Data Engineering| 65000|   Mumbai|
# +-----------+------------+----------------+------+---------+

# %%
df.filter(df.department=="AI Engineering").show()
# Out:
# +-----------+-----------+--------------+------+---------+
# |employee_id|       name|    department|salary|     city|
# +-----------+-----------+--------------+------+---------+
# |        102|Priya Reddy|AI Engineering| 85000|Bangalore|
# +-----------+-----------+--------------+------+---------+

# %%
df.filter((df.salary>=70000) & (df.salary<=90000)).show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# +-----------+------------+-----------------+------+---------+

# %%
df.filter((df.city=="Hyderabad") & (df.salary>70000)).show()
# Out:
# +-----------+------------+----------------+------+---------+
# |employee_id|        name|      department|salary|     city|
# +-----------+------------+----------------+------+---------+
# |        101|Rahul Sharma|Data Engineering| 75000|Hyderabad|
# +-----------+------------+----------------+------+---------+

# %%
df.filter((df.city=="Bangalore") | (df.city=="Chennai")).show()
# Out:
# +-----------+-----------+--------------+------+---------+
# |employee_id|       name|    department|salary|     city|
# +-----------+-----------+--------------+------+---------+
# |        102|Priya Reddy|AI Engineering| 85000|Bangalore|
# |        104|Sneha Patel|  Data Science| 95000|  Chennai|
# +-----------+-----------+--------------+------+---------+

# %%
df.filter(df.city.isin("Hyderabad","Mumbai","Delhi")).show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# +-----------+------------+-----------------+------+---------+

# %%
df.filter(df.department.isin("Data Engineering","AI Engineering")).show()
# Out:
# +-----------+------------+----------------+------+---------+
# |employee_id|        name|      department|salary|     city|
# +-----------+------------+----------------+------+---------+
# |        101|Rahul Sharma|Data Engineering| 75000|Hyderabad|
# |        102| Priya Reddy|  AI Engineering| 85000|Bangalore|
# |        103|  Amit Kumar|Data Engineering| 65000|   Mumbai|
# +-----------+------------+----------------+------+---------+

# %%
df.orderBy("salary").show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# +-----------+------------+-----------------+------+---------+

# %%
df.orderBy(df.salary.desc()).show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# +-----------+------------+-----------------+------+---------+

# %%
df.orderBy("name").show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# +-----------+------------+-----------------+------+---------+

# %%
df.orderBy("city","salary").show()
# Out:
# +-----------+------------+-----------------+------+---------+
# |employee_id|        name|       department|salary|     city|
# +-----------+------------+-----------------+------+---------+
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|
# +-----------+------------+-----------------+------+---------+

# %%
df=df.withColumn("bonus",df.salary*0.10)
df.show()
# Out:
# +-----------+------------+-----------------+------+---------+------+
# |employee_id|        name|       department|salary|     city| bonus|
# +-----------+------------+-----------------+------+---------+------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|7500.0|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|8500.0|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|6500.0|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|9500.0|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|8000.0|
# +-----------+------------+-----------------+------+---------+------+

# %%
df=df.withColumn("tax",df.salary*0.05)
df.show()
# Out:
# +-----------+------------+-----------------+------+---------+------+------+
# |employee_id|        name|       department|salary|     city| bonus|   tax|
# +-----------+------------+-----------------+------+---------+------+------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|7500.0|3750.0|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|8500.0|4250.0|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|6500.0|3250.0|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|9500.0|4750.0|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|8000.0|4000.0|
# +-----------+------------+-----------------+------+---------+------+------+

# %%
df=df.withColumn("annual_salary",df.salary*12)
df.show()
# Out:
# +-----------+------------+-----------------+------+---------+------+-------+-------------+
# |employee_id|        name|       department|salary|     city| bonus|    tax|annual_salary|
# +-----------+------------+-----------------+------+---------+------+-------+-------------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|7500.0| 900000|       900000|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|8500.0|1020000|      1020000|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|6500.0| 780000|       780000|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|9500.0|1140000|      1140000|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|8000.0| 960000|       960000|
# +-----------+------------+-----------------+------+---------+------+-------+-------------+

# %%
df = df.withColumn("salary_after_bonus", df.salary + df.bonus)
df.show()
# Out:
# +-----------+------------+-----------------+------+---------+------+-------+-------------+------------------+
# |employee_id|        name|       department|salary|     city| bonus|    tax|annual_salary|salary_after_bonus|
# +-----------+------------+-----------------+------+---------+------+-------+-------------+------------------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|7500.0| 900000|       900000|           82500.0|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|8500.0|1020000|      1020000|           93500.0|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|6500.0| 780000|       780000|           71500.0|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|9500.0|1140000|      1140000|          104500.0|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|8000.0| 960000|       960000|           88000.0|
# +-----------+------------+-----------------+------+---------+------+-------+-------------+------------------+

# %%
df.withColumnRenamed("salary","monthly_salary").show()
# Out:
# +-----------+------------+-----------------+--------------+---------+------+-------+-------------+------------------+
# |employee_id|        name|       department|monthly_salary|     city| bonus|    tax|annual_salary|salary_after_bonus|
# +-----------+------------+-----------------+--------------+---------+------+-------+-------------+------------------+
# |        101|Rahul Sharma| Data Engineering|         75000|Hyderabad|7500.0| 900000|       900000|           82500.0|
# |        102| Priya Reddy|   AI Engineering|         85000|Bangalore|8500.0|1020000|      1020000|           93500.0|
# |        103|  Amit Kumar| Data Engineering|         65000|   Mumbai|6500.0| 780000|       780000|           71500.0|
# |        104| Sneha Patel|     Data Science|         95000|  Chennai|9500.0|1140000|      1140000|          104500.0|
# |        105|  Farhan Ali|Cloud Engineering|         80000|    Delhi|8000.0| 960000|       960000|           88000.0|
# +-----------+------------+-----------------+--------------+---------+------+-------+-------------+------------------+

# %%
df.withColumnRenamed("department", "team").show()
# Out:
# +-----------+------------+-----------------+------+---------+------+-------+-------------+------------------+
# |employee_id|        name|             team|salary|     city| bonus|    tax|annual_salary|salary_after_bonus|
# +-----------+------------+-----------------+------+---------+------+-------+-------------+------------------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|7500.0| 900000|       900000|           82500.0|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|8500.0|1020000|      1020000|           93500.0|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|6500.0| 780000|       780000|           71500.0|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|9500.0|1140000|      1140000|          104500.0|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|8000.0| 960000|       960000|           88000.0|
# +-----------+------------+-----------------+------+---------+------+-------+-------------+------------------+

# %%
from pyspark.sql import functions as F

# %%
df.select(F.sum("salary")).show()
# Out:
# +-----------+
# |sum(salary)|
# +-----------+
# |     400000|
# +-----------+

# %%
df.select(F.avg("salary")).show()
# Out:
# +-----------+
# |avg(salary)|
# +-----------+
# |    80000.0|
# +-----------+

# %%
df.select(F.max("salary")).show()
# Out:
# +-----------+
# |max(salary)|
# +-----------+
# |      95000|
# +-----------+

# %%
df.select(F.min("salary")).show()
# Out:
# +-----------+
# |min(salary)|
# +-----------+
# |      65000|
# +-----------+

# %%
print(df.count())
# Out:
# 5

# %%
df.groupBy("department").count().show()
# Out:
# +-----------------+-----+
# |       department|count|
# +-----------------+-----+
# | Data Engineering|    2|
# |   AI Engineering|    1|
# |Cloud Engineering|    1|
# |     Data Science|    1|
# +-----------------+-----+

# %%
df.groupBy("department").avg("salary").show()
# Out:
# +-----------------+-----------+
# |       department|avg(salary)|
# +-----------------+-----------+
# | Data Engineering|    70000.0|
# |   AI Engineering|    85000.0|
# |Cloud Engineering|    80000.0|
# |     Data Science|    95000.0|
# +-----------------+-----------+

# %%
df.groupBy("department").max("salary").show()
# Out:
# +-----------------+-----------+
# |       department|max(salary)|
# +-----------------+-----------+
# | Data Engineering|      75000|
# |   AI Engineering|      85000|
# |Cloud Engineering|      80000|
# |     Data Science|      95000|
# +-----------------+-----------+

# %%
df.groupBy("department").min("salary").show()
# Out:
# +-----------------+-----------+
# |       department|min(salary)|
# +-----------------+-----------+
# | Data Engineering|      65000|
# |   AI Engineering|      85000|
# |Cloud Engineering|      80000|
# |     Data Science|      95000|
# +-----------------+-----------+

# %%
df.groupBy("department").sum("salary").show()
# Out:
# +-----------------+-----------+
# |       department|sum(salary)|
# +-----------------+-----------+
# | Data Engineering|     140000|
# |   AI Engineering|      85000|
# |Cloud Engineering|      80000|
# |     Data Science|      95000|
# +-----------------+-----------+

# %%
df.select("department").distinct().show()
# Out:
# +-----------------+
# |       department|
# +-----------------+
# | Data Engineering|
# |   AI Engineering|
# |Cloud Engineering|
# |     Data Science|
# +-----------------+

# %%
df.select("city").distinct().show()
# Out:
# +---------+
# |     city|
# +---------+
# |Bangalore|
# |Hyderabad|
# |  Chennai|
# |   Mumbai|
# |    Delhi|
# +---------+

# %%
df.select("department").distinct().count()
# Out:
# 4

# %%
df.orderBy(df.salary.desc()).show(3)
# Out:
# +-----------+-----------+-----------------+------+---------+------+-------+-------------+------------------+
# |employee_id|       name|       department|salary|     city| bonus|    tax|annual_salary|salary_after_bonus|
# +-----------+-----------+-----------------+------+---------+------+-------+-------------+------------------+
# |        104|Sneha Patel|     Data Science| 95000|  Chennai|9500.0|1140000|      1140000|          104500.0|
# |        102|Priya Reddy|   AI Engineering| 85000|Bangalore|8500.0|1020000|      1020000|           93500.0|
# |        105| Farhan Ali|Cloud Engineering| 80000|    Delhi|8000.0| 960000|       960000|           88000.0|
# +-----------+-----------+-----------------+------+---------+------+-------+-------------+------------------+
# only showing top 3 rows

# %%
df.orderBy("salary").show(1)
# Out:
# +-----------+----------+----------------+------+------+------+------+-------------+------------------+
# |employee_id|      name|      department|salary|  city| bonus|   tax|annual_salary|salary_after_bonus|
# +-----------+----------+----------------+------+------+------+------+-------------+------------------+
# |        103|Amit Kumar|Data Engineering| 65000|Mumbai|6500.0|780000|       780000|           71500.0|
# +-----------+----------+----------------+------+------+------+------+-------------+------------------+
# only showing top 1 row

# %%
df.filter(df.name.startswith("R")).show()
# Out:
# +-----------+------------+----------------+------+---------+------+------+-------------+------------------+
# |employee_id|        name|      department|salary|     city| bonus|   tax|annual_salary|salary_after_bonus|
# +-----------+------------+----------------+------+---------+------+------+-------------+------------------+
# |        101|Rahul Sharma|Data Engineering| 75000|Hyderabad|7500.0|900000|       900000|           82500.0|
# +-----------+------------+----------------+------+---------+------+------+-------------+------------------+

# %%
df.filter(df.name.contains("a")).show()
# Out:
# +-----------+------------+-----------------+------+---------+------+-------+-------------+------------------+
# |employee_id|        name|       department|salary|     city| bonus|    tax|annual_salary|salary_after_bonus|
# +-----------+------------+-----------------+------+---------+------+-------+-------------+------------------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|7500.0| 900000|       900000|           82500.0|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|8500.0|1020000|      1020000|           93500.0|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|6500.0| 780000|       780000|           71500.0|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|9500.0|1140000|      1140000|          104500.0|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|8000.0| 960000|       960000|           88000.0|
# +-----------+------------+-----------------+------+---------+------+-------+-------------+------------------+

# %%
df.filter(df.department.contains("Engineering")).show()
# Out:
# +-----------+------------+-----------------+------+---------+------+-------+-------------+------------------+
# |employee_id|        name|       department|salary|     city| bonus|    tax|annual_salary|salary_after_bonus|
# +-----------+------------+-----------------+------+---------+------+-------+-------------+------------------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|7500.0| 900000|       900000|           82500.0|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|8500.0|1020000|      1020000|           93500.0|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|6500.0| 780000|       780000|           71500.0|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|8000.0| 960000|       960000|           88000.0|
# +-----------+------------+-----------------+------+---------+------+-------+-------------+------------------+

# %%
df = df.withColumn(
    "salary_category",
    F.when(df.salary >= 85000, "High")
     .when(df.salary >= 75000, "Medium")
     .otherwise("Low")
)

df.show()
# Out:
# +-----------+------------+-----------------+------+---------+------+-------+-------------+------------------+---------------+
# |employee_id|        name|       department|salary|     city| bonus|    tax|annual_salary|salary_after_bonus|salary_category|
# +-----------+------------+-----------------+------+---------+------+-------+-------------+------------------+---------------+
# |        101|Rahul Sharma| Data Engineering| 75000|Hyderabad|7500.0| 900000|       900000|           82500.0|         Medium|
# |        102| Priya Reddy|   AI Engineering| 85000|Bangalore|8500.0|1020000|      1020000|           93500.0|           High|
# |        103|  Amit Kumar| Data Engineering| 65000|   Mumbai|6500.0| 780000|       780000|           71500.0|            Low|
# |        104| Sneha Patel|     Data Science| 95000|  Chennai|9500.0|1140000|      1140000|          104500.0|           High|
# |        105|  Farhan Ali|Cloud Engineering| 80000|    Delhi|8000.0| 960000|       960000|           88000.0|         Medium|
# +-----------+------------+-----------------+------+---------+------+-------+-------------+------------------+---------------+

# %%
df.groupBy("salary_category").count().show()
# Out:
# +---------------+-----+
# |salary_category|count|
# +---------------+-----+
# |           High|    2|
# |         Medium|    2|
# |            Low|    1|
# +---------------+-----+
