# %%
employee_data = [
    (101, "Akshaya", "IT", 50000),
    (102, "Sam", "HR", 45000),
    (103, "John", "Finance", 60000),
    (104, "Priya", "IT", 55000)
]

df = spark.createDataFrame(
    employee_data,
    ["emp_id", "name", "department", "salary"]
)

display(df)

print("Employee Load Completed")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>department</th><th>salary</th></tr></thead><tbody><tr><td>101</td><td>Akshaya</td><td>IT</td><td>50000</td></tr><tr><td>102</td><td>Sam</td><td>HR</td><td>45000</td></tr><tr><td>103</td><td>John</td><td>Finance</td><td>60000</td></tr><tr><td>104</td><td>Priya</td><td>IT</td><td>55000</td></tr></tbody></table></div>
# Employee Load Completed
